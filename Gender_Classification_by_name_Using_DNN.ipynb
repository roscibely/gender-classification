# %% [markdown]
# # 1. Gender Classification Using Deep Neural Networks (DNN)

# %% [markdown]
# ## 1.1 Necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Dense, Activation, Dropout, Flatten
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1.2 Download the dataset

# %%
import requests
url = "https://data.brasil.io/dataset/genero-nomes/nomes.csv.gz"
filename = url.split("/")[-1]
with open(filename, "wb") as f:
    r = requests.get(url)
    f.write(r.content)

df = pd.read_csv('nomes.csv.gz') 
df.head()
# Out:
#                                    alternative_names  ... ratio
# 0  AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...  ...   1.0
# 1                                         ARAAO|ARAO  ...   1.0
# 2                       AHARON|AROM|ARON|ARYON|HARON  ...   1.0
# 3                            ADA|ADAH|ADAR|ADHA|HADA  ...   1.0
# 4                                                NaN  ...   1.0
#
# [5 rows x 9 columns]

# %% [markdown]
# ### 1.2.1 Preparing the data

# %%
y = df['classification'].astype("category").cat.codes.values # y labels into numbers
names = df['first_name'].apply(lambda x: x.lower()) # input names

# %% [markdown]
# ## 1.3 Encoding Words

# %%
maxlen = 20
vocab = set(' '.join([str(i) for i in names]))
vocab.add('END')
len_vocab = len(vocab)
char_index = dict((c, i) for i, c in enumerate(vocab))

# %%
x = []
# Builds an empty line with a 1 at the index of character
def set_flag(i):
    tmp = np.zeros(len_vocab);
    tmp[i] = 1
    return list(tmp)

# Truncate names and create the matrix
def prepare_encod_names(X):
    new_list = []
    trunc_train_name = [str(i)[0:maxlen] for i in X]

    for i in trunc_train_name:
        tmp = [set_flag(char_index[j]) for j in str(i)]
        for k in range(0,maxlen - len(str(i))):
            tmp.append(set_flag(char_index["END"]))
        new_list.append(tmp)

    return new_list


x = prepare_encod_names(names.values)

# %% [markdown]
# ## 1.4 Split the data into test and train

# %%
# train, val, test set will be 60%, 20%, 20% of the dataset respectively
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=1)

x_train = np.asarray(x_train)
y_train = np.asarray(y_train)
x_test = np.asarray(x_test)
y_test = np.asarray(y_test)
x_val = np.asarray(x_val)
y_val = np.asarray(y_val)

# %% [markdown]
# ## 1.5 Building the DNN Model

# %%
model = Sequential()
model.add(Dense(12, input_dim=28, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=0.9)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# print the model
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 12)                348
# _________________________________________________________________
# dense_34 (Dense)             (None, 128)               1664
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 10,333
# Trainable params: 10,333
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 1.6 Fitting the data into model

# %%
history = model.fit(x_train, y_train, batch_size=128, epochs=5, validation_data =(x_val, y_val))
scores = model.evaluate(x_test, y_test) 
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Epoch 1/5
# 473/473 [==============================] - 8s 17ms/step - loss: 0.6807 - accuracy: 0.5641 - val_loss: 0.6794 - val_accuracy: 0.5656
# Epoch 2/5
# 473/473 [==============================] - 8s 17ms/step - loss: 0.6807 - accuracy: 0.5643 - val_loss: 0.6795 - val_accuracy: 0.5656
# Epoch 3/5
# 473/473 [==============================] - 8s 17ms/step - loss: 0.6808 - accuracy: 0.5640 - val_loss: 0.6797 - val_accuracy: 0.5650
# Epoch 4/5
# 473/473 [==============================] - 8s 17ms/step - loss: 0.6808 - accuracy: 0.5640 - val_loss: 0.6794 - val_accuracy: 0.5659
# Epoch 5/5
# 473/473 [==============================] - 8s 17ms/step - loss: 0.6807 - accuracy: 0.5643 - val_loss: 0.6806 - val_accuracy: 0.5656
# 630/630 [==============================] - 1s 2ms/step - loss: 0.6815 - accuracy: 0.5601
# Accuracy: 56.01%

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'], 'g--')
plt.plot(history.history['val_accuracy'], 'r')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'], 'g--')
plt.plot(history.history['val_loss'], 'r')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
y_pred =(model.predict(x_test) > 0.5).astype("int32")
plt.figure(2)
plt.plot(y_test[6:50], 'g--x')
plt.plot(y_pred[6:50], 'r:o')
plt.ylabel('class')
plt.xlabel('data')
plt.legend(['Real', 'Predict'], loc='upper left')
plt.show()
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 28) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28), dtype=tf.float32, name='dense_33_input'), name='dense_33_input', description="created by layer 'dense_33_input'"), but it was called on an input with incompatible shape (None, 20, 28).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-dd361eb6f5b5> in <module>()
#       2 plt.figure(2)
#       3 plt.plot(y_test[6:50], 'g--x')
# ----> 4 plt.plot(y_pred[6:50], 'r:o')
#       5 plt.ylabel('class')
#       6 plt.xlabel('data')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
# --> 345             raise ValueError(f"x and y can be no greater than 2-D, but have "
#     346                              f"shapes {x.shape} and {y.shape}")
#     347         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (44,) and (44, 20, 1)
